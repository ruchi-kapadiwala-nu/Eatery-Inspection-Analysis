# %%
# !pip install ydata_profiling

# %%
# !pip install pandas

# %%
from ydata_profiling import ProfileReport
import pandas as pd

# %%
df = pd.read_csv('Restaurant_and_Food_Establishment_Inspections.tsv', sep='\t')
print(df)
# Out:
#                                       Restaurant Name Inspection Type  \
# 0                                      MICKLE CHICKEN         Routine
# 1                               TOM THUMB - JUICE BAR         Routine
# 2                                BROOKDALE WHITE ROCK         Routine
# 3                               CHURCH'S CHICKEN #201         Routine
# 4                     PEAK PREPARATORY-PRIMARY SCHOOL         Routine
# ...                                               ...             ...
# 26124        BELMONT VILLAGE TURTLE CREEK TENANT, LLC         Routine
# 26125  THE HIGHLAND DALLAS CURIO COLLECTION BY HILTON         Routine
# 26126                                     BEST BURGER         Routine
# 26127                                I LOVE EGG ROLLS         Routine
# 26128                          DEARL'S GROCERY (DELI)         Routine
#
#       Inspection Date  Inspection Score  Street Number  Street Name  \
# ...

# %%
profile  = ProfileReport(df, title = "Food Inspection Report_Dallas")

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install pyppeteer

# %%
# !pyppeteer-install
# Out:
# [INFO] Starting Chromium download.
# 100% 183M/183M [00:01<00:00, 172Mb/s]
# [INFO] Beginning extraction
# [INFO] Chromium extracted to: /root/.local/share/pyppeteer/local-chromium/1181205
